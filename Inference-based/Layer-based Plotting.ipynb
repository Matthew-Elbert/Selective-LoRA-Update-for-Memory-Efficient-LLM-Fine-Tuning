# %% [markdown]
# # Layer-based Targeting Plotting

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def plot(dir, desc):
    with open(f'./{dir}/gpu_usage_log.json', 'r') as file:
        gpu = json.load(file)

    with open(f'./{dir}/ram_usage_log.json', 'r') as file:
        ram = json.load(file)

    with open(f'./{dir}/training_results_detailed_test.json', 'r') as file:
        results= json.load(file)
        baseline_ram= results['baseline_ram_gb']
        baseline_gpu= results['baseline_gpu_gb']


    chunk_size = 10
    gpu=np.array(gpu)-baseline_gpu
    ram=np.array(ram)-baseline_ram
    

    gpu_usage = [
        gpu[i]
        for i in range(0, len(gpu), chunk_size)
    ]

    ram_usage = [
        ram[i]
        for i in range(0, len(ram), chunk_size)
    ]
    
    time_stamps = [x for x in range(len(gpu_usage))]  # Using index as timestamp if actual timestamps are not available
    # time_deltas = (time_stamps - time_stamps[0]).total_seconds() / 60  # Convert to minutes
    
    # Plot GPU and RAM usage over time
    plt.figure(figsize=(12, 6))
    plt.plot(time_stamps, gpu_usage, label='GPU Usage ', color='blue')
    plt.plot(time_stamps, ram_usage, label='RAM Usage', color='orange')
    plt.xlabel('Time')
    plt.ylabel('Usage')
    plt.title(f"GPU and RAM Usage over Time ({desc})")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_loss(dir,desc):
    with open(f'./{dir}/log.json', 'r') as file:
        log = json.load(file)
        
    loss=[x['loss'] for x in log[:-2]]
    step=[x['step'] for x in log[:-2]]
    
    plt.grid(True)
    plt.plot(step,loss)
    plt.xlabel('Number of Steps')
    plt.ylabel('Loss')
    plt.title(f'Training Loss over Number of Steps ({desc})')

def plot_conf_matrix(dir, desc):
    with open(f'./{dir}/prediction_answers.json', 'r') as file:
        res = json.load(file)
    
    preds = res['predictions']
    true = res['labels']
    labels = ['World', 'Sports', 'Business', 'Sci/Tech']

    cm = confusion_matrix(true, preds)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

    # Plot confusion matrix
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f"Confusion Matrix ({desc})")
    plt.show()

# %%
def plot_results(dir):
    with open(f'./{dir}/training_results_detailed_test.json', 'r') as f:
        results = json.load(f)
    
    df = pd.DataFrame(results.items(), columns=['Metric', 'Value'])
    
    # Format value type
    def format_value(row):
        metric, value = row['Metric'], row['Value']
        if metric in ['total_parameters', 'trainable_parameters']:
            return f'{int(value):,}'
        elif metric in ['training_time_seconds', 'test_inference_time_seconds']:
            return f'{value:.2f}s'
        elif 'percentage' in metric:
            return f'{value:.2f}%'
        elif 'gb' in metric.lower():
            return f'{value:.4f} GB'
        else:
            return f'{value:.4f}'
    
    df['Value'] = df.apply(format_value, axis=1)
    display(df.style.hide(axis='index'))

# %% [markdown]
# ### Layer 0 Fine-tune

# %%
plot('results_inference-based_20260311_185448', 'Layer 0 Fine-tune')
plot_loss('results_inference-based_20260311_185448', 'Layer 0 Fine-tune')
plot_conf_matrix('results_inference-based_20260311_185448', 'Layer 0 Fine-tune')
plot_results('results_inference-based_20260311_185448')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0de28">
#   <thead>
#     <tr>
#       <th id="T_0de28_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_0de28_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0de28_row0_col0" class="data row0 col0" >test_accuracy</td>
#       <td id="T_0de28_row0_col1" class="data row0 col1" >0.8991</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row1_col0" class="data row1 col0" >test_accuracy_percentage</td>
#       <td id="T_0de28_row1_col1" class="data row1 col1" >89.91%</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row2_col0" class="data row2 col0" >validation_accuracy</td>
#       <td id="T_0de28_row2_col1" class="data row2 col1" >0.8978</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row3_col0" class="data row3 col0" >training_time_seconds</td>
#       <td id="T_0de28_row3_col1" class="data row3 col1" >920.44s</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row4_col0" class="data row4 col0" >test_inference_time_seconds</td>
#       <td id="T_0de28_row4_col1" class="data row4 col1" >38.58s</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row5_col0" class="data row5 col0" >peak_gpu_memory_during_training_gb</td>
#       <td id="T_0de28_row5_col1" class="data row5 col1" >3.5172 GB</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row6_col0" class="data row6 col0" >peak_ram_usage_during_training_gb</td>
#       <td id="T_0de28_row6_col1" class="data row6 col1" >14.0247 GB</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row7_col0" class="data row7 col0" >gpu_memory_increase_during_training_gb</td>
#       <td id="T_0de28_row7_col1" class="data row7 col1" >2.9870 GB</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row8_col0" class="data row8 col0" >ram_increase_during_training_gb</td>
#       <td id="T_0de28_row8_col1" class="data row8 col1" >0.8521 GB</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row9_col0" class="data row9 col0" >baseline_ram_gb</td>
#       <td id="T_0de28_row9_col1" class="data row9 col1" >13.1725 GB</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row10_col0" class="data row10 col0" >baseline_gpu_gb</td>
#       <td id="T_0de28_row10_col1" class="data row10 col1" >0.5302 GB</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row11_col0" class="data row11 col0" >total_parameters</td>
#       <td id="T_0de28_row11_col1" class="data row11 col1" >142,008,580</td>
#     </tr>
#     <tr>
#       <td id="T_0de28_row12_col0" class="data row12 col0" >trainable_parameters</td>
#       <td id="T_0de28_row12_col1" class="data row12 col1" >110,592</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Layer 5 Fine-tune

# %%
plot('results_inference-based_20260310_200728', 'Layer 5 Fine-tune')
plot_loss('results_inference-based_20260310_200728', 'Layer 5 Fine-tune')
plot_conf_matrix('results_inference-based_20260310_200728', 'Layer 5 Fine-tune')
plot_results('results_inference-based_20260310_200728')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1eaad">
#   <thead>
#     <tr>
#       <th id="T_1eaad_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_1eaad_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1eaad_row0_col0" class="data row0 col0" >test_accuracy</td>
#       <td id="T_1eaad_row0_col1" class="data row0 col1" >0.8646</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row1_col0" class="data row1 col0" >test_accuracy_percentage</td>
#       <td id="T_1eaad_row1_col1" class="data row1 col1" >86.46%</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row2_col0" class="data row2 col0" >validation_accuracy</td>
#       <td id="T_1eaad_row2_col1" class="data row2 col1" >0.8655</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row3_col0" class="data row3 col0" >training_time_seconds</td>
#       <td id="T_1eaad_row3_col1" class="data row3 col1" >1367.71s</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row4_col0" class="data row4 col0" >test_inference_time_seconds</td>
#       <td id="T_1eaad_row4_col1" class="data row4 col1" >59.12s</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row5_col0" class="data row5 col0" >peak_gpu_memory_during_training_gb</td>
#       <td id="T_1eaad_row5_col1" class="data row5 col1" >1.6210 GB</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row6_col0" class="data row6 col0" >peak_ram_usage_during_training_gb</td>
#       <td id="T_1eaad_row6_col1" class="data row6 col1" >16.6835 GB</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row7_col0" class="data row7 col0" >gpu_memory_increase_during_training_gb</td>
#       <td id="T_1eaad_row7_col1" class="data row7 col1" >1.0908 GB</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row8_col0" class="data row8 col0" >ram_increase_during_training_gb</td>
#       <td id="T_1eaad_row8_col1" class="data row8 col1" >0.8159 GB</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row9_col0" class="data row9 col0" >baseline_ram_gb</td>
#       <td id="T_1eaad_row9_col1" class="data row9 col1" >15.8676 GB</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row10_col0" class="data row10 col0" >baseline_gpu_gb</td>
#       <td id="T_1eaad_row10_col1" class="data row10 col1" >0.5302 GB</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row11_col0" class="data row11 col0" >total_parameters</td>
#       <td id="T_1eaad_row11_col1" class="data row11 col1" >142,008,580</td>
#     </tr>
#     <tr>
#       <td id="T_1eaad_row12_col0" class="data row12 col0" >trainable_parameters</td>
#       <td id="T_1eaad_row12_col1" class="data row12 col1" >110,592</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Bottom 33% Fine-tune

# %%
plot('results_inference-based_20260311_191916', 'Bottom 33% Fine-tune')
plot_loss('results_inference-based_20260311_191916', 'Bottom 33% Fine-tune')
plot_conf_matrix('results_inference-based_20260311_191916', 'Bottom 33% Fine-tune')
plot_results('results_inference-based_20260311_191916')
# Out:
# <style type="text/css">
# </style>
# <table id="T_011fb">
#   <thead>
#     <tr>
#       <th id="T_011fb_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_011fb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_011fb_row0_col0" class="data row0 col0" >test_accuracy</td>
#       <td id="T_011fb_row0_col1" class="data row0 col1" >0.9039</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row1_col0" class="data row1 col0" >test_accuracy_percentage</td>
#       <td id="T_011fb_row1_col1" class="data row1 col1" >90.39%</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row2_col0" class="data row2 col0" >validation_accuracy</td>
#       <td id="T_011fb_row2_col1" class="data row2 col1" >0.9037</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row3_col0" class="data row3 col0" >training_time_seconds</td>
#       <td id="T_011fb_row3_col1" class="data row3 col1" >934.29s</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row4_col0" class="data row4 col0" >test_inference_time_seconds</td>
#       <td id="T_011fb_row4_col1" class="data row4 col1" >38.78s</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row5_col0" class="data row5 col0" >peak_gpu_memory_during_training_gb</td>
#       <td id="T_011fb_row5_col1" class="data row5 col1" >3.5915 GB</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row6_col0" class="data row6 col0" >peak_ram_usage_during_training_gb</td>
#       <td id="T_011fb_row6_col1" class="data row6 col1" >14.0985 GB</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row7_col0" class="data row7 col0" >gpu_memory_increase_during_training_gb</td>
#       <td id="T_011fb_row7_col1" class="data row7 col1" >3.0608 GB</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row8_col0" class="data row8 col0" >ram_increase_during_training_gb</td>
#       <td id="T_011fb_row8_col1" class="data row8 col1" >0.8616 GB</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row9_col0" class="data row9 col0" >baseline_ram_gb</td>
#       <td id="T_011fb_row9_col1" class="data row9 col1" >13.2369 GB</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row10_col0" class="data row10 col0" >baseline_gpu_gb</td>
#       <td id="T_011fb_row10_col1" class="data row10 col1" >0.5306 GB</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row11_col0" class="data row11 col0" >total_parameters</td>
#       <td id="T_011fb_row11_col1" class="data row11 col1" >142,119,172</td>
#     </tr>
#     <tr>
#       <td id="T_011fb_row12_col0" class="data row12 col0" >trainable_parameters</td>
#       <td id="T_011fb_row12_col1" class="data row12 col1" >221,184</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Top 33% Fine-tune

# %%
plot('results_inference-based_20260311_194406', 'Top 33% Fine-tune')
plot_loss('results_inference-based_20260311_194406', 'Top 33% Fine-tune')
plot_conf_matrix('results_inference-based_20260311_194406', 'Top 33% Fine-tune')
plot_results('results_inference-based_20260311_194406')
# Out:
# <style type="text/css">
# </style>
# <table id="T_54b08">
#   <thead>
#     <tr>
#       <th id="T_54b08_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_54b08_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_54b08_row0_col0" class="data row0 col0" >test_accuracy</td>
#       <td id="T_54b08_row0_col1" class="data row0 col1" >0.8982</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row1_col0" class="data row1 col0" >test_accuracy_percentage</td>
#       <td id="T_54b08_row1_col1" class="data row1 col1" >89.82%</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row2_col0" class="data row2 col0" >validation_accuracy</td>
#       <td id="T_54b08_row2_col1" class="data row2 col1" >0.9001</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row3_col0" class="data row3 col0" >training_time_seconds</td>
#       <td id="T_54b08_row3_col1" class="data row3 col1" >842.96s</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row4_col0" class="data row4 col0" >test_inference_time_seconds</td>
#       <td id="T_54b08_row4_col1" class="data row4 col1" >38.83s</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row5_col0" class="data row5 col0" >peak_gpu_memory_during_training_gb</td>
#       <td id="T_54b08_row5_col1" class="data row5 col1" >1.6631 GB</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row6_col0" class="data row6 col0" >peak_ram_usage_during_training_gb</td>
#       <td id="T_54b08_row6_col1" class="data row6 col1" >14.1215 GB</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row7_col0" class="data row7 col0" >gpu_memory_increase_during_training_gb</td>
#       <td id="T_54b08_row7_col1" class="data row7 col1" >1.1325 GB</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row8_col0" class="data row8 col0" >ram_increase_during_training_gb</td>
#       <td id="T_54b08_row8_col1" class="data row8 col1" >0.8566 GB</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row9_col0" class="data row9 col0" >baseline_ram_gb</td>
#       <td id="T_54b08_row9_col1" class="data row9 col1" >13.2649 GB</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row10_col0" class="data row10 col0" >baseline_gpu_gb</td>
#       <td id="T_54b08_row10_col1" class="data row10 col1" >0.5306 GB</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row11_col0" class="data row11 col0" >total_parameters</td>
#       <td id="T_54b08_row11_col1" class="data row11 col1" >142,119,172</td>
#     </tr>
#     <tr>
#       <td id="T_54b08_row12_col0" class="data row12 col0" >trainable_parameters</td>
#       <td id="T_54b08_row12_col1" class="data row12 col1" >221,184</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Bottom 50% Fine-tune

# %%
plot('results_inference-based_20260312_142107', 'Bottom 50% Fine-tune')
plot_loss('results_inference-based_20260312_142107', 'Bottom 50% Fine-tune')
plot_conf_matrix('results_inference-based_20260312_142107', 'Bottom 50% Fine-tune')
plot_results('results_inference-based_20260312_142107')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4cb7c">
#   <thead>
#     <tr>
#       <th id="T_4cb7c_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_4cb7c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4cb7c_row0_col0" class="data row0 col0" >test_accuracy</td>
#       <td id="T_4cb7c_row0_col1" class="data row0 col1" >0.9075</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row1_col0" class="data row1 col0" >test_accuracy_percentage</td>
#       <td id="T_4cb7c_row1_col1" class="data row1 col1" >90.75%</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row2_col0" class="data row2 col0" >validation_accuracy</td>
#       <td id="T_4cb7c_row2_col1" class="data row2 col1" >0.9091</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row3_col0" class="data row3 col0" >training_time_seconds</td>
#       <td id="T_4cb7c_row3_col1" class="data row3 col1" >955.18s</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row4_col0" class="data row4 col0" >test_inference_time_seconds</td>
#       <td id="T_4cb7c_row4_col1" class="data row4 col1" >38.83s</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row5_col0" class="data row5 col0" >peak_gpu_memory_during_training_gb</td>
#       <td id="T_4cb7c_row5_col1" class="data row5 col1" >3.6725 GB</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row6_col0" class="data row6 col0" >peak_ram_usage_during_training_gb</td>
#       <td id="T_4cb7c_row6_col1" class="data row6 col1" >16.1247 GB</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row7_col0" class="data row7 col0" >gpu_memory_increase_during_training_gb</td>
#       <td id="T_4cb7c_row7_col1" class="data row7 col1" >3.1415 GB</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row8_col0" class="data row8 col0" >ram_increase_during_training_gb</td>
#       <td id="T_4cb7c_row8_col1" class="data row8 col1" >0.8640 GB</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row9_col0" class="data row9 col0" >baseline_ram_gb</td>
#       <td id="T_4cb7c_row9_col1" class="data row9 col1" >15.2607 GB</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row10_col0" class="data row10 col0" >baseline_gpu_gb</td>
#       <td id="T_4cb7c_row10_col1" class="data row10 col1" >0.5310 GB</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row11_col0" class="data row11 col0" >total_parameters</td>
#       <td id="T_4cb7c_row11_col1" class="data row11 col1" >142,229,764</td>
#     </tr>
#     <tr>
#       <td id="T_4cb7c_row12_col0" class="data row12 col0" >trainable_parameters</td>
#       <td id="T_4cb7c_row12_col1" class="data row12 col1" >331,776</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Top 50% Fine-tune

# %%
plot('results_inference-based_20260312_130217', 'Top 50% Fine-tune')
plot_loss('results_inference-based_20260312_130217', 'Top 50% Fine-tune')
plot_conf_matrix('results_inference-based_20260312_130217', 'Top 50% Fine-tune')
plot_results('results_inference-based_20260312_130217')
# Out:
# <style type="text/css">
# </style>
# <table id="T_22630">
#   <thead>
#     <tr>
#       <th id="T_22630_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_22630_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_22630_row0_col0" class="data row0 col0" >test_accuracy</td>
#       <td id="T_22630_row0_col1" class="data row0 col1" >0.9087</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row1_col0" class="data row1 col0" >test_accuracy_percentage</td>
#       <td id="T_22630_row1_col1" class="data row1 col1" >90.87%</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row2_col0" class="data row2 col0" >validation_accuracy</td>
#       <td id="T_22630_row2_col1" class="data row2 col1" >0.9095</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row3_col0" class="data row3 col0" >training_time_seconds</td>
#       <td id="T_22630_row3_col1" class="data row3 col1" >886.95s</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row4_col0" class="data row4 col0" >test_inference_time_seconds</td>
#       <td id="T_22630_row4_col1" class="data row4 col1" >38.77s</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row5_col0" class="data row5 col0" >peak_gpu_memory_during_training_gb</td>
#       <td id="T_22630_row5_col1" class="data row5 col1" >2.2930 GB</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row6_col0" class="data row6 col0" >peak_ram_usage_during_training_gb</td>
#       <td id="T_22630_row6_col1" class="data row6 col1" >16.2088 GB</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row7_col0" class="data row7 col0" >gpu_memory_increase_during_training_gb</td>
#       <td id="T_22630_row7_col1" class="data row7 col1" >1.7619 GB</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row8_col0" class="data row8 col0" >ram_increase_during_training_gb</td>
#       <td id="T_22630_row8_col1" class="data row8 col1" >1.2082 GB</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row9_col0" class="data row9 col0" >baseline_ram_gb</td>
#       <td id="T_22630_row9_col1" class="data row9 col1" >15.0006 GB</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row10_col0" class="data row10 col0" >baseline_gpu_gb</td>
#       <td id="T_22630_row10_col1" class="data row10 col1" >0.5310 GB</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row11_col0" class="data row11 col0" >total_parameters</td>
#       <td id="T_22630_row11_col1" class="data row11 col1" >142,229,764</td>
#     </tr>
#     <tr>
#       <td id="T_22630_row12_col0" class="data row12 col0" >trainable_parameters</td>
#       <td id="T_22630_row12_col1" class="data row12 col1" >331,776</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Interval Fine-tune (Layer 1, Layer 3, Layer 5)

# %%
plot('results_inference-based_20260311_202807', 'Interval Fine-tune')
plot_loss('results_inference-based_20260311_202807', 'Interval Fine-tune')
plot_conf_matrix('results_inference-based_20260311_202807', 'Interval Fine-tune')
plot_results('results_inference-based_20260311_202807')
# Out:
# <style type="text/css">
# </style>
# <table id="T_63419">
#   <thead>
#     <tr>
#       <th id="T_63419_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_63419_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63419_row0_col0" class="data row0 col0" >test_accuracy</td>
#       <td id="T_63419_row0_col1" class="data row0 col1" >0.9109</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row1_col0" class="data row1 col0" >test_accuracy_percentage</td>
#       <td id="T_63419_row1_col1" class="data row1 col1" >91.09%</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row2_col0" class="data row2 col0" >validation_accuracy</td>
#       <td id="T_63419_row2_col1" class="data row2 col1" >0.9123</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row3_col0" class="data row3 col0" >training_time_seconds</td>
#       <td id="T_63419_row3_col1" class="data row3 col1" >932.14s</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row4_col0" class="data row4 col0" >test_inference_time_seconds</td>
#       <td id="T_63419_row4_col1" class="data row4 col1" >38.88s</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row5_col0" class="data row5 col0" >peak_gpu_memory_during_training_gb</td>
#       <td id="T_63419_row5_col1" class="data row5 col1" >3.1204 GB</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row6_col0" class="data row6 col0" >peak_ram_usage_during_training_gb</td>
#       <td id="T_63419_row6_col1" class="data row6 col1" >14.1047 GB</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row7_col0" class="data row7 col0" >gpu_memory_increase_during_training_gb</td>
#       <td id="T_63419_row7_col1" class="data row7 col1" >2.5894 GB</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row8_col0" class="data row8 col0" >ram_increase_during_training_gb</td>
#       <td id="T_63419_row8_col1" class="data row8 col1" >0.8353 GB</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row9_col0" class="data row9 col0" >baseline_ram_gb</td>
#       <td id="T_63419_row9_col1" class="data row9 col1" >13.2695 GB</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row10_col0" class="data row10 col0" >baseline_gpu_gb</td>
#       <td id="T_63419_row10_col1" class="data row10 col1" >0.5310 GB</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row11_col0" class="data row11 col0" >total_parameters</td>
#       <td id="T_63419_row11_col1" class="data row11 col1" >142,229,764</td>
#     </tr>
#     <tr>
#       <td id="T_63419_row12_col0" class="data row12 col0" >trainable_parameters</td>
#       <td id="T_63419_row12_col1" class="data row12 col1" >331,776</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### All Results

# %%
def plot_all_results():
    dirs = [
        ('results_inference-based_20260311_185448', 'Layer 0'),
        ('results_inference-based_20260310_200728', 'Layer 5'),
        ('results_inference-based_20260311_191916', 'Bottom 33%'),
        ('results_inference-based_20260311_194406', 'Top 33%'),
        ('results_inference-based_20260312_142107', 'Bottom 50%'),
        ('results_inference-based_20260312_130217', 'Top 50%'),
        ('results_inference-based_20260311_202807', 'Interval')
    ]
    
    all_dfs = []
    for dir, label in dirs:
        with open(f'./{dir}/training_results_detailed_test.json', 'r') as f:
            results = json.load(f)
        
        def format_value(row):
            metric, value = row['Metric'], row['Value']
            if metric in ['total_parameters', 'trainable_parameters']:
                return f'{int(value):,}'
            elif metric in ['training_time_seconds', 'test_inference_time_seconds']:
                return f'{value:.2f}s'
            elif 'percentage' in metric:
                return f'{value:.2f}%'
            elif 'gb' in metric.lower():
                return f'{value:.4f} GB'
            else:
                return f'{value:.4f}'
        
        df = pd.DataFrame(results.items(), columns=['Metric', label])
        df[label] = df.apply(lambda row: format_value(pd.Series({'Metric': row['Metric'], 'Value': row[label]})), axis=1)
        all_dfs.append(df)
    
    # Merge
    combined = all_dfs[0]
    for df in all_dfs[1:]:
        combined = combined.merge(df, on='Metric')
    
    display(combined.style.hide(axis='index'))

plot_all_results()
# Out:
# <style type="text/css">
# </style>
# <table id="T_44725">
#   <thead>
#     <tr>
#       <th id="T_44725_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_44725_level0_col1" class="col_heading level0 col1" >Layer 0</th>
#       <th id="T_44725_level0_col2" class="col_heading level0 col2" >Layer 5</th>
#       <th id="T_44725_level0_col3" class="col_heading level0 col3" >Bottom 33%</th>
#       <th id="T_44725_level0_col4" class="col_heading level0 col4" >Top 33%</th>
#       <th id="T_44725_level0_col5" class="col_heading level0 col5" >Bottom 50%</th>
#       <th id="T_44725_level0_col6" class="col_heading level0 col6" >Top 50%</th>
#       <th id="T_44725_level0_col7" class="col_heading level0 col7" >Interval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_44725_row0_col0" class="data row0 col0" >test_accuracy</td>
#       <td id="T_44725_row0_col1" class="data row0 col1" >0.8991</td>
#       <td id="T_44725_row0_col2" class="data row0 col2" >0.8646</td>
#       <td id="T_44725_row0_col3" class="data row0 col3" >0.9039</td>
#       <td id="T_44725_row0_col4" class="data row0 col4" >0.8982</td>
#       <td id="T_44725_row0_col5" class="data row0 col5" >0.9075</td>
#       <td id="T_44725_row0_col6" class="data row0 col6" >0.9087</td>
#       <td id="T_44725_row0_col7" class="data row0 col7" >0.9109</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row1_col0" class="data row1 col0" >test_accuracy_percentage</td>
#       <td id="T_44725_row1_col1" class="data row1 col1" >89.91%</td>
#       <td id="T_44725_row1_col2" class="data row1 col2" >86.46%</td>
#       <td id="T_44725_row1_col3" class="data row1 col3" >90.39%</td>
#       <td id="T_44725_row1_col4" class="data row1 col4" >89.82%</td>
#       <td id="T_44725_row1_col5" class="data row1 col5" >90.75%</td>
#       <td id="T_44725_row1_col6" class="data row1 col6" >90.87%</td>
#       <td id="T_44725_row1_col7" class="data row1 col7" >91.09%</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row2_col0" class="data row2 col0" >validation_accuracy</td>
#       <td id="T_44725_row2_col1" class="data row2 col1" >0.8978</td>
#       <td id="T_44725_row2_col2" class="data row2 col2" >0.8655</td>
#       <td id="T_44725_row2_col3" class="data row2 col3" >0.9037</td>
#       <td id="T_44725_row2_col4" class="data row2 col4" >0.9001</td>
#       <td id="T_44725_row2_col5" class="data row2 col5" >0.9091</td>
#       <td id="T_44725_row2_col6" class="data row2 col6" >0.9095</td>
#       <td id="T_44725_row2_col7" class="data row2 col7" >0.9123</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row3_col0" class="data row3 col0" >training_time_seconds</td>
#       <td id="T_44725_row3_col1" class="data row3 col1" >920.44s</td>
#       <td id="T_44725_row3_col2" class="data row3 col2" >1367.71s</td>
#       <td id="T_44725_row3_col3" class="data row3 col3" >934.29s</td>
#       <td id="T_44725_row3_col4" class="data row3 col4" >842.96s</td>
#       <td id="T_44725_row3_col5" class="data row3 col5" >955.18s</td>
#       <td id="T_44725_row3_col6" class="data row3 col6" >886.95s</td>
#       <td id="T_44725_row3_col7" class="data row3 col7" >932.14s</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row4_col0" class="data row4 col0" >test_inference_time_seconds</td>
#       <td id="T_44725_row4_col1" class="data row4 col1" >38.58s</td>
#       <td id="T_44725_row4_col2" class="data row4 col2" >59.12s</td>
#       <td id="T_44725_row4_col3" class="data row4 col3" >38.78s</td>
#       <td id="T_44725_row4_col4" class="data row4 col4" >38.83s</td>
#       <td id="T_44725_row4_col5" class="data row4 col5" >38.83s</td>
#       <td id="T_44725_row4_col6" class="data row4 col6" >38.77s</td>
#       <td id="T_44725_row4_col7" class="data row4 col7" >38.88s</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row5_col0" class="data row5 col0" >peak_gpu_memory_during_training_gb</td>
#       <td id="T_44725_row5_col1" class="data row5 col1" >3.5172 GB</td>
#       <td id="T_44725_row5_col2" class="data row5 col2" >1.6210 GB</td>
#       <td id="T_44725_row5_col3" class="data row5 col3" >3.5915 GB</td>
#       <td id="T_44725_row5_col4" class="data row5 col4" >1.6631 GB</td>
#       <td id="T_44725_row5_col5" class="data row5 col5" >3.6725 GB</td>
#       <td id="T_44725_row5_col6" class="data row5 col6" >2.2930 GB</td>
#       <td id="T_44725_row5_col7" class="data row5 col7" >3.1204 GB</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row6_col0" class="data row6 col0" >peak_ram_usage_during_training_gb</td>
#       <td id="T_44725_row6_col1" class="data row6 col1" >14.0247 GB</td>
#       <td id="T_44725_row6_col2" class="data row6 col2" >16.6835 GB</td>
#       <td id="T_44725_row6_col3" class="data row6 col3" >14.0985 GB</td>
#       <td id="T_44725_row6_col4" class="data row6 col4" >14.1215 GB</td>
#       <td id="T_44725_row6_col5" class="data row6 col5" >16.1247 GB</td>
#       <td id="T_44725_row6_col6" class="data row6 col6" >16.2088 GB</td>
#       <td id="T_44725_row6_col7" class="data row6 col7" >14.1047 GB</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row7_col0" class="data row7 col0" >gpu_memory_increase_during_training_gb</td>
#       <td id="T_44725_row7_col1" class="data row7 col1" >2.9870 GB</td>
#       <td id="T_44725_row7_col2" class="data row7 col2" >1.0908 GB</td>
#       <td id="T_44725_row7_col3" class="data row7 col3" >3.0608 GB</td>
#       <td id="T_44725_row7_col4" class="data row7 col4" >1.1325 GB</td>
#       <td id="T_44725_row7_col5" class="data row7 col5" >3.1415 GB</td>
#       <td id="T_44725_row7_col6" class="data row7 col6" >1.7619 GB</td>
#       <td id="T_44725_row7_col7" class="data row7 col7" >2.5894 GB</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row8_col0" class="data row8 col0" >ram_increase_during_training_gb</td>
#       <td id="T_44725_row8_col1" class="data row8 col1" >0.8521 GB</td>
#       <td id="T_44725_row8_col2" class="data row8 col2" >0.8159 GB</td>
#       <td id="T_44725_row8_col3" class="data row8 col3" >0.8616 GB</td>
#       <td id="T_44725_row8_col4" class="data row8 col4" >0.8566 GB</td>
#       <td id="T_44725_row8_col5" class="data row8 col5" >0.8640 GB</td>
#       <td id="T_44725_row8_col6" class="data row8 col6" >1.2082 GB</td>
#       <td id="T_44725_row8_col7" class="data row8 col7" >0.8353 GB</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row9_col0" class="data row9 col0" >baseline_ram_gb</td>
#       <td id="T_44725_row9_col1" class="data row9 col1" >13.1725 GB</td>
#       <td id="T_44725_row9_col2" class="data row9 col2" >15.8676 GB</td>
#       <td id="T_44725_row9_col3" class="data row9 col3" >13.2369 GB</td>
#       <td id="T_44725_row9_col4" class="data row9 col4" >13.2649 GB</td>
#       <td id="T_44725_row9_col5" class="data row9 col5" >15.2607 GB</td>
#       <td id="T_44725_row9_col6" class="data row9 col6" >15.0006 GB</td>
#       <td id="T_44725_row9_col7" class="data row9 col7" >13.2695 GB</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row10_col0" class="data row10 col0" >baseline_gpu_gb</td>
#       <td id="T_44725_row10_col1" class="data row10 col1" >0.5302 GB</td>
#       <td id="T_44725_row10_col2" class="data row10 col2" >0.5302 GB</td>
#       <td id="T_44725_row10_col3" class="data row10 col3" >0.5306 GB</td>
#       <td id="T_44725_row10_col4" class="data row10 col4" >0.5306 GB</td>
#       <td id="T_44725_row10_col5" class="data row10 col5" >0.5310 GB</td>
#       <td id="T_44725_row10_col6" class="data row10 col6" >0.5310 GB</td>
#       <td id="T_44725_row10_col7" class="data row10 col7" >0.5310 GB</td>
#     </tr>
#     <tr>
#       <td id="T_44725_row11_col0" class="data row11 col0" >total_parameters</td>
#       <td id="T_44725_row11_col1" class="data row11 col1" >142,008,580</td>
#       <td id="T_44725_row11_col2" class="data row11 col2" >142,008,580</td>
#       <td id="T_44725_row11_col3" class="data row11 col3" >142,119,172</td>
#       <td id="T_44725_row11_col4" class="data row11 col4" >142,119,172</td>
#       <td id="T_44725_row11_col5" class="data row11 col5" >142,229,764</td>
#       <td id="T_44725_row11_col6" class="data row11 col6" >142,229,764</td>
#       <td id="T_44725_row11_col7" class="data r
